# %%
import json
import pandas as pd
import findspark
findspark.init()

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, explode


spark = SparkSession.builder.appName("ProcessingDataset").getOrCreate()
spark.conf.set('spark.sql.caseSensitive', True)

# %% [markdown]
# ## Preprocessing for the Video_Games.jsonl - User Reviews Data

# %% [markdown]
# ### Drop unnecessary column (images) in Video_Games

# %%
reviews_df = spark.read.json("Video_Games.jsonl")

reviews_df.printSchema()

reviews_df.show(5)
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachment_type: string (nullable = true)
#  |    |    |-- large_image_url: string (nullable = true)
#  |    |    |-- medium_image_url: string (nullable = true)
#  |    |    |-- small_image_url: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#
# +----------+------------+------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |      asin|helpful_vote|images|parent_asin|rating|                text|    timestamp|               title|             user_id|verified_purchase|
# +----------+------------+------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |B07DJWBYKP|           0|    []| B07DK1H3H5|   4.0|I’m playing on ps...|1608186804795|It’s pretty sexua...|AGCI7FAH4GL5FI65H...|             true|
# |B00ZS80PC2|           1|    []| B07SRWRH5D|   5.0|Nostalgic fun.  A...|1587051114941|    Good. A bit slow|AGCI7FAH4GL5FI65H...|            false|
# |B01FEHJYUU|           0|    []| B07MFMFW34|   5.0|This was an order...|1490877431000|... an order for ...|AGXVBIUFLFGMVLATY...|             true|
# |B07GXJHRVK|           0|    []| B0BCHWZX95|   5.0|These work great,...|1577637634017|Great alt to pro ...|AFTC6ZR5IKNRDG5JC...|             true|
# |B00HUWA45W|           0|    []| B00HUWA45W|   5.0|I would recommend...|1427591932000|       solid product|AFTC6ZR5IKNRDG5JC...|             true|
# +----------+------------+------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# only showing top 5 rows

# %%
reviews_df = reviews_df.drop('images')

# %%
reviews_df.printSchema()
reviews_df.show(5)
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |      asin|helpful_vote|parent_asin|rating|                text|    timestamp|               title|             user_id|verified_purchase|
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# |B07DJWBYKP|           0| B07DK1H3H5|   4.0|I’m playing on ps...|1608186804795|It’s pretty sexua...|AGCI7FAH4GL5FI65H...|             true|
# |B00ZS80PC2|           1| B07SRWRH5D|   5.0|Nostalgic fun.  A...|1587051114941|    Good. A bit slow|AGCI7FAH4GL5FI65H...|            false|
# |B01FEHJYUU|           0| B07MFMFW34|   5.0|This was an order...|1490877431000|... an order for ...|AGXVBIUFLFGMVLATY...|             true|
# |B07GXJHRVK|           0| B0BCHWZX95|   5.0|These work great,...|1577637634017|Great alt to pro ...|AFTC6ZR5IKNRDG5JC...|             true|
# |B00HUWA45W|           0| B00HUWA45W|   5.0|I would recommend...|1427591932000|       solid product|AFTC6ZR5IKNRDG5JC...|             true|
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+
# only showing top 5 rows

# %% [markdown]
# ### Cleaning and modifying data

# %%
from pyspark.sql.functions import from_unixtime, col

# %% [markdown]
# Datetime Column

# %%
#Create a new datetime column from timestamp (Unix time)
reviews_df = reviews_df.withColumn("datetime", from_unixtime((col("timestamp") / 1000).cast("long")))
reviews_df.printSchema()
reviews_df.show(1)
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#  |-- datetime: string (nullable = true)
#
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+-------------------+
# |      asin|helpful_vote|parent_asin|rating|                text|    timestamp|               title|             user_id|verified_purchase|           datetime|
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+-------------------+
# |B07DJWBYKP|           0| B07DK1H3H5|   4.0|I’m playing on ps...|1608186804795|It’s pretty sexua...|AGCI7FAH4GL5FI65H...|             true|2020-12-17 13:33:24|
# +----------+------------+-----------+------+--------------------+-------------+--------------------+--------------------+-----------------+-------------------+
# only showing top 1 row

# %% [markdown]
# review_id : id for each review

# %%
from pyspark.sql.functions import monotonically_increasing_id

reviews_df = reviews_df.withColumn("review_id", monotonically_increasing_id())

# %% [markdown]
# text_length: length of the text field

# %%
from pyspark.sql.functions import length

# %%
# Độ dài nội dung phản hồi
reviews_df = reviews_df.withColumn("text_length", length(col("text")))

# %% [markdown]
# rating_label: Categorize the rating score of user's review into 3 classes: negative, neutral and positive

# %%
from pyspark.sql.functions import when

# %%
reviews_df = reviews_df.withColumn(
    "rating_label",
    when(col("rating") <= 2, "negative")
    .when(col("rating") == 3, "neutral")
    .otherwise("positive")
)

# %% [markdown]
# ### Save the cleaned version into parquet

# %%
reviews_df.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful_vote: long (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
#  |-- datetime: string (nullable = true)
#  |-- review_id: long (nullable = false)
#  |-- text_length: integer (nullable = true)
#  |-- rating_label: string (nullable = false)

# %%
#Drop the original timestamp column
reviews_df = reviews_df.drop('timestamp')

# %%
reviews_df = reviews_df.select("review_id", "title",\
                               "rating", "rating_label", "user_id",\
                                "asin", "parent_asin",\
                                "text", "text_length",\
                                "helpful_vote", "verified_purchase",\
                                "datetime")

# %%
reviews_df.show(1)
# Out:
# +---------+--------------------+------+------------+--------------------+----------+-----------+--------------------+-----------+------------+-----------------+-------------------+
# |review_id|               title|rating|rating_label|             user_id|      asin|parent_asin|                text|text_length|helpful_vote|verified_purchase|           datetime|
# +---------+--------------------+------+------------+--------------------+----------+-----------+--------------------+-----------+------------+-----------------+-------------------+
# |        0|It’s pretty sexua...|   4.0|    positive|AGCI7FAH4GL5FI65H...|B07DJWBYKP| B07DK1H3H5|I’m playing on ps...|        226|           0|             true|2020-12-17 13:33:24|
# +---------+--------------------+------+------------+--------------------+----------+-----------+--------------------+-----------+------------+-----------------+-------------------+
# only showing top 1 row

# %%
reviews_df.write.mode("overwrite").parquet("Dataset/user_reviews.parquet")

# %% [markdown]
# ## Preprocessing for the meta_Video_Games.jsonl - Product metadata

# %% [markdown]
# ### Drop unnecessary columns (images and videos) in meta_Video_Games

# %%
metadata_df = spark.read.json("meta_Video_Games.jsonl")
metadata_df.printSchema()
# Out:
# root
#  |-- author: struct (nullable = true)
#  |    |-- about: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- avatar: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- average_rating: double (nullable = true)
#  |-- bought_together: string (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- details: struct (nullable = true)
#  |    |-- AC Adapter Current: string (nullable = true)
#  |    |-- Access Location: string (nullable = true)
#  |    |-- Accessory Connection Type: string (nullable = true)
#  |    |-- Action: string (nullable = true)
#  |    |-- Active Ingredients: string (nullable = true)
#  |    |-- Actors: string (nullable = true)
#  |    |-- Actuator Type: string (nullable = true)
#  |    |-- Additional product features: string (nullable = true)
#  |    |-- Adjustable Length: string (nullable = true)
#  |    |-- Age Range (Description): string (nullable = true)
#  |    |-- Age Range Description: string (nullable = true)
#  |    |-- Air Flow Capacity: string (nullable = true)
#  |    |-- Alarm Clock: string (nullable = true)
#  |    |-- Alert Type: string (nullable = true)
#  |    |-- Allergen Information: string (nullable = true)
#  |    |-- Amperage: string (nullable = true)
#  |    |-- Annual Energy Consumption: string (nullable = true)
#  |    |-- Answering System Type: string (nullable = true)
#  |    |-- Antenna: string (nullable = true)
#  |    |-- Arch Type: string (nullable = true)
#  |    |-- Are Batteries Included: string (nullable = true)
#  |    |-- Area Lighting Classification: string (nullable = true)
#  |    |-- Arm Style: string (nullable = true)
#  |    |-- Aspect Ratio: string (nullable = true)
#  |    |-- Assembled Diameter: string (nullable = true)
#  |    |-- Assembled Height: string (nullable = true)
#  |    |-- Assembled Length: string (nullable = true)
#  |    |-- Assembled Seat Height: string (nullable = true)
#  |    |-- Assembled Width: string (nullable = true)
#  |    |-- Assembly Required: string (nullable = true)
#  |    |-- Assembly Required No: string (nullable = true)
#  |    |-- Assembly required: string (nullable = true)
#  |    |-- Athlete: string (nullable = true)
#  |    |-- Audio Description: string (nullable = true)
#  |    |-- Audio Driver Size: string (nullable = true)
#  |    |-- Audio Jack: string (nullable = true)
#  |    |-- Audio Latency: string (nullable = true)
#  |    |-- Audio Output Mode: string (nullable = true)
#  |    |-- Audio Sensitivity: string (nullable = true)
#  |    |-- Auto Focus Technology: string (nullable = true)
#  |    |-- Auto Part Position: string (nullable = true)
#  |    |-- Average Battery Life: string (nullable = true)
#  |    |-- Average Battery Life (in hours): string (nullable = true)
#  |    |-- Back Material: string (nullable = true)
#  |    |-- Back Material Type: string (nullable = true)
#  |    |-- Back Style: string (nullable = true)
#  |    |-- Band Color: string (nullable = true)
#  |    |-- Band Material Type: string (nullable = true)
#  |    |-- Base Material: string (nullable = true)
#  |    |-- Base Type: string (nullable = true)
#  |    |-- Batteries: string (nullable = true)
#  |    |-- Batteries Included?: string (nullable = true)
#  |    |-- Batteries Required?: string (nullable = true)
#  |    |-- Batteries required: string (nullable = true)
#  |    |-- Battery Capacity: string (nullable = true)
#  |    |-- Battery Cell Composition: string (nullable = true)
#  |    |-- Battery Cell Type: string (nullable = true)
#  |    |-- Battery Description: string (nullable = true)
#  |    |-- Battery Life: string (nullable = true)
#  |    |-- Battery Power Rating: string (nullable = true)
#  |    |-- Battery Type: string (nullable = true)
#  |    |-- Battery Weight: string (nullable = true)
#  |    |-- Battery type: string (nullable = true)
#  |    |-- Best Sellers Rank: struct (nullable = true)
#  |    |    |-- 3D Viewing Glasses: long (nullable = true)
#  |    |    |-- 3DO Accessories: long (nullable = true)
#  |    |    |-- 3DO Games: long (nullable = true)
#  |    |    |-- 3DO Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Action & Adventure: long (nullable = true)
#  |    |    |-- Action Figures: long (nullable = true)
#  |    |    |-- Amazon Renewed: long (nullable = true)
#  |    |    |-- Amplifier Accessories: long (nullable = true)
#  |    |    |-- Arcade & Table Games: long (nullable = true)
#  |    |    |-- Arena Rock: long (nullable = true)
#  |    |    |-- Arts & Crafts Supplies: long (nullable = true)
#  |    |    |-- Arts, Crafts & Sewing: long (nullable = true)
#  |    |    |-- Atari 2600 Accessories: long (nullable = true)
#  |    |    |-- Atari 2600 Consoles: long (nullable = true)
#  |    |    |-- Atari 2600 Games: long (nullable = true)
#  |    |    |-- Atari 2600 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Atari 5200 Accessories: long (nullable = true)
#  |    |    |-- Atari 5200 Consoles: long (nullable = true)
#  |    |    |-- Atari 5200 Games: long (nullable = true)
#  |    |    |-- Atari 5200 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Atari 7800 Accessories: long (nullable = true)
#  |    |    |-- Atari 7800 Consoles: long (nullable = true)
#  |    |    |-- Atari 7800 Games: long (nullable = true)
#  |    |    |-- Atari 7800 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Atari Jaguar Accessories: long (nullable = true)
#  |    |    |-- Atari Jaguar Consoles: long (nullable = true)
#  |    |    |-- Atari Jaguar Games: long (nullable = true)
#  |    |    |-- Atari Jaguar Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Atari Legacy Systems: long (nullable = true)
#  |    |    |-- Atari Lynx Accessories: long (nullable = true)
#  |    |    |-- Atari Lynx Games: long (nullable = true)
#  |    |    |-- Atari Lynx Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Automotive: long (nullable = true)
#  |    |    |-- Automotive Exterior Accessories: long (nullable = true)
#  |    |    |-- Backpacks: long (nullable = true)
#  |    |    |-- Banjos: long (nullable = true)
#  |    |    |-- Beauty Tools & Accessories: long (nullable = true)
#  |    |    |-- Blu-ray: long (nullable = true)
#  |    |    |-- Board Games: long (nullable = true)
#  |    |    |-- Books: long (nullable = true)
#  |    |    |-- Brain Teaser Puzzles: long (nullable = true)
#  |    |    |-- British Invasion Rock: long (nullable = true)
#  |    |    |-- Cabinet Hardware: long (nullable = true)
#  |    |    |-- Camera & Camcorder Batteries & Chargers: long (nullable = true)
#  |    |    |-- Camera Bags & Cases: long (nullable = true)
#  |    |    |-- Camping & Hiking Equipment: long (nullable = true)
#  |    |    |-- Car Electronics: long (nullable = true)
#  |    |    |-- Card Games: long (nullable = true)
#  |    |    |-- Cell Phone Accessories: long (nullable = true)
#  |    |    |-- Cell Phone Basic Cases: long (nullable = true)
#  |    |    |-- Cell Phone Cables & Adapters: long (nullable = true)
#  |    |    |-- Cell Phone Case & Cover Bundles: long (nullable = true)
#  |    |    |-- Cell Phone Cases & Covers: long (nullable = true)
#  |    |    |-- Cell Phone Chargers & Power Adapters: long (nullable = true)
#  |    |    |-- Cell Phone Décor: long (nullable = true)
#  |    |    |-- Cell Phone Gaming Controllers: long (nullable = true)
#  |    |    |-- Cell Phone Gaming Finger Sleeves: long (nullable = true)
#  |    |    |-- Cell Phone Replacement Parts: long (nullable = true)
#  |    |    |-- Cell Phone Sleeves: long (nullable = true)
#  |    |    |-- Cell Phone Stands: long (nullable = true)
#  |    |    |-- Cell Phone Virtual Reality: long (nullable = true)
#  |    |    |-- Cell Phones & Accessories: long (nullable = true)
#  |    |    |-- Children's Software: long (nullable = true)
#  |    |    |-- Christmas Ball Ornaments: long (nullable = true)
#  |    |    |-- Circuit Breakers: long (nullable = true)
#  |    |    |-- Classic Rock Supergroups: long (nullable = true)
#  |    |    |-- Classic Southern Rock: long (nullable = true)
#  |    |    |-- Climate Pledge Friendly: long (nullable = true)
#  |    |    |-- Climate Pledge Friendly: Computers: long (nullable = true)
#  |    |    |-- Climate Pledge Friendly: Electronics: long (nullable = true)
#  |    |    |-- ColecoVision Accessories: long (nullable = true)
#  |    |    |-- ColecoVision Consoles: long (nullable = true)
#  |    |    |-- ColecoVision Games: long (nullable = true)
#  |    |    |-- Collectible Card Game Decks & Sets: long (nullable = true)
#  |    |    |-- Collectible Card Games: long (nullable = true)
#  |    |    |-- Collectible Trading Card Albums: long (nullable = true)
#  |    |    |-- Commodore 64 Accessories: long (nullable = true)
#  |    |    |-- Commodore 64 Consoles: long (nullable = true)
#  |    |    |-- Commodore 64 Games: long (nullable = true)
#  |    |    |-- Commodore 64 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Commodore Amiga Accessories: long (nullable = true)
#  |    |    |-- Commodore Amiga Consoles: long (nullable = true)
#  |    |    |-- Commodore Amiga Games: long (nullable = true)
#  |    |    |-- Commodore Amiga Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Commodore Legacy Systems: long (nullable = true)
#  |    |    |-- Computer Accessories & Peripherals: long (nullable = true)
#  |    |    |-- Computer Audio & Video Accessories: long (nullable = true)
#  |    |    |-- Computer Blue Light Blocking Glasses: long (nullable = true)
#  |    |    |-- Computer Cable Adapters: long (nullable = true)
#  |    |    |-- Computer Components: long (nullable = true)
#  |    |    |-- Computer Headsets: long (nullable = true)
#  |    |    |-- Computer Keyboard & Mouse Combos: long (nullable = true)
#  |    |    |-- Computer Keyboards: long (nullable = true)
#  |    |    |-- Computer Keyboards, Mice & Accessories: long (nullable = true)
#  |    |    |-- Computer Mice: long (nullable = true)
#  |    |    |-- Computer Monitors: long (nullable = true)
#  |    |    |-- Computer Networking: long (nullable = true)
#  |    |    |-- Computer Recording Equipment: long (nullable = true)
#  |    |    |-- Computer Recording MIDI Controllers: long (nullable = true)
#  |    |    |-- Computers & Tablets: long (nullable = true)
#  |    |    |-- Craft Supplies & Materials: long (nullable = true)
#  |    |    |-- DVD: long (nullable = true)
#  |    |    |-- DVD Games: long (nullable = true)
#  |    |    |-- Data Storage: long (nullable = true)
#  |    |    |-- Display Stands: long (nullable = true)
#  |    |    |-- Dolls: long (nullable = true)
#  |    |    |-- Early Development & Activity Toys: long (nullable = true)
#  |    |    |-- Electronic Learning & Education Toys: long (nullable = true)
#  |    |    |-- Electronics: long (nullable = true)
#  |    |    |-- Electronics Accessories & Supplies: long (nullable = true)
#  |    |    |-- Emblems: long (nullable = true)
#  |    |    |-- Exercise Balls & Accessories: long (nullable = true)
#  |    |    |-- External Hard Drives: long (nullable = true)
#  |    |    |-- Folk: long (nullable = true)
#  |    |    |-- Foot & Hand Care: long (nullable = true)
#  |    |    |-- Football Equipment: long (nullable = true)
#  |    |    |-- Funk: long (nullable = true)
#  |    |    |-- Furniture: long (nullable = true)
#  |    |    |-- GEM Box Microconsole: long (nullable = true)
#  |    |    |-- Game Accessories: long (nullable = true)
#  |    |    |-- Game Boy Accessories: long (nullable = true)
#  |    |    |-- Game Boy Advance Accessories: long (nullable = true)
#  |    |    |-- Game Boy Advance Consoles: long (nullable = true)
#  |    |    |-- Game Boy Advance Games: long (nullable = true)
#  |    |    |-- Game Boy Color Accessories: long (nullable = true)
#  |    |    |-- Game Boy Color Consoles: long (nullable = true)
#  |    |    |-- Game Boy Color Games: long (nullable = true)
#  |    |    |-- Game Boy Color Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Game Boy Consoles: long (nullable = true)
#  |    |    |-- Game Boy Games: long (nullable = true)
#  |    |    |-- Game Boy Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Game Boy Legacy Systems: long (nullable = true)
#  |    |    |-- GameBoy Advance Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- GameCube Accessories: long (nullable = true)
#  |    |    |-- GameCube Consoles: long (nullable = true)
#  |    |    |-- GameCube Games: long (nullable = true)
#  |    |    |-- GameCube Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Games & Accessories: long (nullable = true)
#  |    |    |-- Golf Equipment: long (nullable = true)
#  |    |    |-- HDMI Cables: long (nullable = true)
#  |    |    |-- Hand Tools: long (nullable = true)
#  |    |    |-- Handheld Legacy Game Systems: long (nullable = true)
#  |    |    |-- Headphone Adapters: long (nullable = true)
#  |    |    |-- Headphone Amps: long (nullable = true)
#  |    |    |-- Headphone Cases: long (nullable = true)
#  |    |    |-- Headphones & Earbuds: long (nullable = true)
#  |    |    |-- Headphones, Earbuds & Accessories: long (nullable = true)
#  |    |    |-- Hobby Remote & App Controlled Vehicles & Parts: long (nullable = true)
#  |    |    |-- Home & Kitchen: long (nullable = true)
#  |    |    |-- Home Audio & Theater Products: long (nullable = true)
#  |    |    |-- Home Audio Accessories: long (nullable = true)
#  |    |    |-- Home Cinema Cables: long (nullable = true)
#  |    |    |-- Home Decorative Accessories: long (nullable = true)
#  |    |    |-- Home Décor Accents: long (nullable = true)
#  |    |    |-- Home Storage & Organization: long (nullable = true)
#  |    |    |-- Home Theater Accessories: long (nullable = true)
#  |    |    |-- Home Theater Audio: long (nullable = true)
#  |    |    |-- Household Supplies: long (nullable = true)
#  |    |    |-- Insulated Beverage Containers: long (nullable = true)
#  |    |    |-- Intellivision Accessories: long (nullable = true)
#  |    |    |-- Intellivision Games: long (nullable = true)
#  |    |    |-- Intellivision Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Jigsaw Puzzles: long (nullable = true)
#  |    |    |-- Kids' Backpacks: long (nullable = true)
#  |    |    |-- Kids' Dress Up & Pretend Play: long (nullable = true)
#  |    |    |-- Kids' Drum & Percussion Instruments: long (nullable = true)
#  |    |    |-- Kids' Electronics: long (nullable = true)
#  |    |    |-- Kids' Handheld Games: long (nullable = true)
#  |    |    |-- Kids' Home Store: long (nullable = true)
#  |    |    |-- Kids' Party Decorations: long (nullable = true)
#  |    |    |-- Kids' Party Favor Sets: long (nullable = true)
#  |    |    |-- Kids' Party Supplies: long (nullable = true)
#  |    |    |-- Kids' Play Dinosaur & Prehistoric Creature Figures: long (nullable = true)
#  |    |    |-- Kids' Play People Figures: long (nullable = true)
#  |    |    |-- Kitchen & Dining: long (nullable = true)
#  |    |    |-- Kitchen & Table Linens: long (nullable = true)
#  |    |    |-- Kitchen Sink Faucets: long (nullable = true)
#  |    |    |-- Laptop Accessories: long (nullable = true)
#  |    |    |-- Legacy Systems: long (nullable = true)
#  |    |    |-- Leisure Sports & Games Equipment: long (nullable = true)
#  |    |    |-- Linux Games: long (nullable = true)
#  |    |    |-- Living Room Furniture: long (nullable = true)
#  |    |    |-- MP3 & MP4 Player Accessories: long (nullable = true)
#  |    |    |-- Mac Accessories: long (nullable = true)
#  |    |    |-- Mac Game Controllers: long (nullable = true)
#  |    |    |-- Mac Game Flight Controls: long (nullable = true)
#  |    |    |-- Mac Game Headsets: long (nullable = true)
#  |    |    |-- Mac Game Joysticks: long (nullable = true)
#  |    |    |-- Mac Game Steering Wheels: long (nullable = true)
#  |    |    |-- Mac Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- Mac Games & Accessories: long (nullable = true)
#  |    |    |-- Mac Gaming Keyboards: long (nullable = true)
#  |    |    |-- Mac Gaming Mice: long (nullable = true)
#  |    |    |-- Mac-compatible Games: long (nullable = true)
#  |    |    |-- Magic Kits & Accessories: long (nullable = true)
#  |    |    |-- Media Storage: long (nullable = true)
#  |    |    |-- Memory Cards: long (nullable = true)
#  |    |    |-- Metal: long (nullable = true)
#  |    |    |-- Microconsoles: long (nullable = true)
#  |    |    |-- Miniature Novelty Toys: long (nullable = true)
#  |    |    |-- Mouse Pads: long (nullable = true)
#  |    |    |-- Mouse Pads & Wrist Rests: long (nullable = true)
#  |    |    |-- Movies: long (nullable = true)
#  |    |    |-- Movies & TV: long (nullable = true)
#  |    |    |-- Music Recording Equipment: long (nullable = true)
#  |    |    |-- Musical Instruments: long (nullable = true)
#  |    |    |-- Musical Soundtracks & Scores: long (nullable = true)
#  |    |    |-- NEOGEO Pocket Consoles: long (nullable = true)
#  |    |    |-- NEOGEO Pocket Game Hardware Accessories: long (nullable = true)
#  |    |    |-- NEOGEO Pocket Games: long (nullable = true)
#  |    |    |-- NEOGEO Pocket Games & Hardware: long (nullable = true)
#  |    |    |-- NES Accessories: long (nullable = true)
#  |    |    |-- NES Consoles: long (nullable = true)
#  |    |    |-- NES Games: long (nullable = true)
#  |    |    |-- NES Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Accessories: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Accessory Kits: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Adapters: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Batteries: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Cables: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Cables & Adapters: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Cases & Storage: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Chargers: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Consoles: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Consoles, Games & Accessories: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Downloadable Content: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Faceplates: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Games: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Hand Grips: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Headsets: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Protectors: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Skins: long (nullable = true)
#  |    |    |-- Nintendo 3DS & 2DS Stylus Pens: long (nullable = true)
#  |    |    |-- Nintendo 64 Accessories: long (nullable = true)
#  |    |    |-- Nintendo 64 Consoles: long (nullable = true)
#  |    |    |-- Nintendo 64 Games: long (nullable = true)
#  |    |    |-- Nintendo 64 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Nintendo DS Accessories: long (nullable = true)
#  |    |    |-- Nintendo DS Accessory Kits: long (nullable = true)
#  |    |    |-- Nintendo DS Adapters: long (nullable = true)
#  |    |    |-- Nintendo DS Batteries: long (nullable = true)
#  |    |    |-- Nintendo DS Cables: long (nullable = true)
#  |    |    |-- Nintendo DS Cables & Adapters: long (nullable = true)
#  |    |    |-- Nintendo DS Cases & Storage: long (nullable = true)
#  |    |    |-- Nintendo DS Chargers: long (nullable = true)
#  |    |    |-- Nintendo DS Consoles: long (nullable = true)
#  |    |    |-- Nintendo DS Games: long (nullable = true)
#  |    |    |-- Nintendo DS Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Nintendo DS Hand Grips: long (nullable = true)
#  |    |    |-- Nintendo DS Headsets: long (nullable = true)
#  |    |    |-- Nintendo DS Stylus Pens: long (nullable = true)
#  |    |    |-- Nintendo Legacy Systems: long (nullable = true)
#  |    |    |-- Nintendo Switch Accessories: long (nullable = true)
#  |    |    |-- Nintendo Switch Batteries & Chargers: long (nullable = true)
#  |    |    |-- Nintendo Switch Cables & Adapters: long (nullable = true)
#  |    |    |-- Nintendo Switch Cases & Storage: long (nullable = true)
#  |    |    |-- Nintendo Switch Consoles: long (nullable = true)
#  |    |    |-- Nintendo Switch Consoles, Games & Accessories: long (nullable = true)
#  |    |    |-- Nintendo Switch Controllers: long (nullable = true)
#  |    |    |-- Nintendo Switch Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- Nintendo Switch Games: long (nullable = true)
#  |    |    |-- Nintendo Switch Hand Grips: long (nullable = true)
#  |    |    |-- Nintendo Switch Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Nintendo Switch Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- Nintendo Switch Repair Tools & Replacement Parts: long (nullable = true)
#  |    |    |-- Nintendo Switch Screen Protectors: long (nullable = true)
#  |    |    |-- Nintendo Switch Skin & Protector Sets: long (nullable = true)
#  |    |    |-- Nintendo Switch Thumb Grips: long (nullable = true)
#  |    |    |-- Nintendo eShop Store Currency & Points Cards: long (nullable = true)
#  |    |    |-- Nintendo eShop Store Currency Cards: long (nullable = true)
#  |    |    |-- Nintendo eShop Subscriptions: long (nullable = true)
#  |    |    |-- Novelty Toys & Amusements: long (nullable = true)
#  |    |    |-- Numeric Keypads: long (nullable = true)
#  |    |    |-- Nvidia Shield Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Office & School Supplies: long (nullable = true)
#  |    |    |-- Office Carts & Stands: long (nullable = true)
#  |    |    |-- Office Platforms, Stands & Shelves: long (nullable = true)
#  |    |    |-- Office Products: long (nullable = true)
#  |    |    |-- On-Ear Headphones: long (nullable = true)
#  |    |    |-- Our Brands: long (nullable = true)
#  |    |    |-- Outdoor Generators & Portable Power: long (nullable = true)
#  |    |    |-- Ouya Consoles, Games & Accessories: long (nullable = true)
#  |    |    |-- Over-Ear Headphones: long (nullable = true)
#  |    |    |-- PC Accessories: long (nullable = true)
#  |    |    |-- PC Game Controllers: long (nullable = true)
#  |    |    |-- PC Game Flight Controls: long (nullable = true)
#  |    |    |-- PC Game Headsets: long (nullable = true)
#  |    |    |-- PC Game Joysticks: long (nullable = true)
#  |    |    |-- PC Game Light Guns: long (nullable = true)
#  |    |    |-- PC Game Music Controllers: long (nullable = true)
#  |    |    |-- PC Game Racing Wheels: long (nullable = true)
#  |    |    |-- PC Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- PC Games & Accessories: long (nullable = true)
#  |    |    |-- PC Gaming Keyboards: long (nullable = true)
#  |    |    |-- PC Gaming Mice: long (nullable = true)
#  |    |    |-- PC Virtual Reality: long (nullable = true)
#  |    |    |-- PC Virtual Reality Accessories: long (nullable = true)
#  |    |    |-- PC Virtual Reality Cameras: long (nullable = true)
#  |    |    |-- PC Virtual Reality Controllers: long (nullable = true)
#  |    |    |-- PC Virtual Reality Headsets: long (nullable = true)
#  |    |    |-- PC-compatible Games: long (nullable = true)
#  |    |    |-- Paint, Wall Treatments & Supplies: long (nullable = true)
#  |    |    |-- Patio, Lawn & Garden: long (nullable = true)
#  |    |    |-- Pest Repellents: long (nullable = true)
#  |    |    |-- Photographic Studio Photo Backgrounds: long (nullable = true)
#  |    |    |-- Play Figure Vehicles: long (nullable = true)
#  |    |    |-- PlayStation 2 Accessories: long (nullable = true)
#  |    |    |-- PlayStation 2 Consoles: long (nullable = true)
#  |    |    |-- PlayStation 2 Games: long (nullable = true)
#  |    |    |-- PlayStation 2 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation 3 Accessories: long (nullable = true)
#  |    |    |-- PlayStation 3 Accessory Kits: long (nullable = true)
#  |    |    |-- PlayStation 3 Adapters: long (nullable = true)
#  |    |    |-- PlayStation 3 Batteries: long (nullable = true)
#  |    |    |-- PlayStation 3 Batteries & Chargers: long (nullable = true)
#  |    |    |-- PlayStation 3 Cables: long (nullable = true)
#  |    |    |-- PlayStation 3 Cables & Adapters: long (nullable = true)
#  |    |    |-- PlayStation 3 Cases & Storage: long (nullable = true)
#  |    |    |-- PlayStation 3 Chargers: long (nullable = true)
#  |    |    |-- PlayStation 3 Consoles: long (nullable = true)
#  |    |    |-- PlayStation 3 Controllers: long (nullable = true)
#  |    |    |-- PlayStation 3 Cooling Systems: long (nullable = true)
#  |    |    |-- PlayStation 3 Downloadable Content: long (nullable = true)
#  |    |    |-- PlayStation 3 Faceplates: long (nullable = true)
#  |    |    |-- PlayStation 3 Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Dance Pads: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Drums: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Guitars: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Joysticks: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Microphones: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Music Controllers: long (nullable = true)
#  |    |    |-- PlayStation 3 Game Racing Wheels: long (nullable = true)
#  |    |    |-- PlayStation 3 Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- PlayStation 3 Games: long (nullable = true)
#  |    |    |-- PlayStation 3 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation 3 Gaming Keyboards: long (nullable = true)
#  |    |    |-- PlayStation 3 Headsets: long (nullable = true)
#  |    |    |-- PlayStation 3 Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- PlayStation 3 Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- PlayStation 3 Remotes: long (nullable = true)
#  |    |    |-- PlayStation 3 Skins: long (nullable = true)
#  |    |    |-- PlayStation 3 Thumb Grips: long (nullable = true)
#  |    |    |-- PlayStation 4 Accessories: long (nullable = true)
#  |    |    |-- PlayStation 4 Accessory Kits: long (nullable = true)
#  |    |    |-- PlayStation 4 Adapters: long (nullable = true)
#  |    |    |-- PlayStation 4 Batteries: long (nullable = true)
#  |    |    |-- PlayStation 4 Batteries & Chargers: long (nullable = true)
#  |    |    |-- PlayStation 4 Cables: long (nullable = true)
#  |    |    |-- PlayStation 4 Cables & Adapters: long (nullable = true)
#  |    |    |-- PlayStation 4 Cases & Storage: long (nullable = true)
#  |    |    |-- PlayStation 4 Chargers: long (nullable = true)
#  |    |    |-- PlayStation 4 Consoles: long (nullable = true)
#  |    |    |-- PlayStation 4 Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation 4 Controllers: long (nullable = true)
#  |    |    |-- PlayStation 4 Cooling Systems: long (nullable = true)
#  |    |    |-- PlayStation 4 Downloadable Content: long (nullable = true)
#  |    |    |-- PlayStation 4 Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- PlayStation 4 Game Racing Wheels: long (nullable = true)
#  |    |    |-- PlayStation 4 Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- PlayStation 4 Games: long (nullable = true)
#  |    |    |-- PlayStation 4 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation 4 Headsets: long (nullable = true)
#  |    |    |-- PlayStation 4 Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- PlayStation 4 Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- PlayStation 4 Remotes: long (nullable = true)
#  |    |    |-- PlayStation 4 Thumb Grips: long (nullable = true)
#  |    |    |-- PlayStation 5 Accessories: long (nullable = true)
#  |    |    |-- PlayStation 5 Batteries & Chargers: long (nullable = true)
#  |    |    |-- PlayStation 5 Cameras & Webcams: long (nullable = true)
#  |    |    |-- PlayStation 5 Cases: long (nullable = true)
#  |    |    |-- PlayStation 5 Cases & Storage: long (nullable = true)
#  |    |    |-- PlayStation 5 Consoles: long (nullable = true)
#  |    |    |-- PlayStation 5 Consoles, Games & Accessories: long (nullable = true)
#  |    |    |-- PlayStation 5 Controllers: long (nullable = true)
#  |    |    |-- PlayStation 5 Faceplates: long (nullable = true)
#  |    |    |-- PlayStation 5 Games: long (nullable = true)
#  |    |    |-- PlayStation 5 Headsets: long (nullable = true)
#  |    |    |-- PlayStation 5 Protectors: long (nullable = true)
#  |    |    |-- PlayStation 5 Racing Wheels: long (nullable = true)
#  |    |    |-- PlayStation 5 Skin & Protector Sets: long (nullable = true)
#  |    |    |-- PlayStation 5 Skins: long (nullable = true)
#  |    |    |-- PlayStation 5 Storage: long (nullable = true)
#  |    |    |-- PlayStation Accessories: long (nullable = true)
#  |    |    |-- PlayStation Consoles: long (nullable = true)
#  |    |    |-- PlayStation Games: long (nullable = true)
#  |    |    |-- PlayStation Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation Legacy Systems: long (nullable = true)
#  |    |    |-- PlayStation Network Store Currency Cards: long (nullable = true)
#  |    |    |-- PlayStation Network Subscriptions: long (nullable = true)
#  |    |    |-- PlayStation VR Accessories: long (nullable = true)
#  |    |    |-- PlayStation VR Hardware: long (nullable = true)
#  |    |    |-- PlayStation VR Headsets: long (nullable = true)
#  |    |    |-- PlayStation Vita Accessories: long (nullable = true)
#  |    |    |-- PlayStation Vita Accessory Kits: long (nullable = true)
#  |    |    |-- PlayStation Vita Adapters: long (nullable = true)
#  |    |    |-- PlayStation Vita Batteries: long (nullable = true)
#  |    |    |-- PlayStation Vita Cables: long (nullable = true)
#  |    |    |-- PlayStation Vita Cases & Storage: long (nullable = true)
#  |    |    |-- PlayStation Vita Chargers: long (nullable = true)
#  |    |    |-- PlayStation Vita Consoles: long (nullable = true)
#  |    |    |-- PlayStation Vita Games: long (nullable = true)
#  |    |    |-- PlayStation Vita Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- PlayStation Vita Hand Grips: long (nullable = true)
#  |    |    |-- PlayStation Vita Headsets: long (nullable = true)
#  |    |    |-- PlayStation Vita Memory: long (nullable = true)
#  |    |    |-- PlayStation Vita Protectors: long (nullable = true)
#  |    |    |-- PlayStation Vita Skins: long (nullable = true)
#  |    |    |-- Playstation 5 Accessory Kits: long (nullable = true)
#  |    |    |-- Playstation TV Microconsole: long (nullable = true)
#  |    |    |-- Plug & Play Video Games: long (nullable = true)
#  |    |    |-- Plush Figure Toys: long (nullable = true)
#  |    |    |-- Pool Rafts & Inflatable Ride-ons: long (nullable = true)
#  |    |    |-- Portable & Handheld TVs: long (nullable = true)
#  |    |    |-- Portable Audio & Video: long (nullable = true)
#  |    |    |-- Pre-Kindergarten Toys: long (nullable = true)
#  |    |    |-- Preschool Toys: long (nullable = true)
#  |    |    |-- Pressure Cooker Accessories: long (nullable = true)
#  |    |    |-- Rap & Hip-Hop: long (nullable = true)
#  |    |    |-- Reading Glasses: long (nullable = true)
#  |    |    |-- Remote Control Extenders: long (nullable = true)
#  |    |    |-- S-Video Cables: long (nullable = true)
#  |    |    |-- SEGA CD Consoles: long (nullable = true)
#  |    |    |-- Scrapbooking & Stamping Supplies: long (nullable = true)
#  |    |    |-- Scrapbooking Stickers & Sticker Machines: long (nullable = true)
#  |    |    |-- Sega CD Accessories: long (nullable = true)
#  |    |    |-- Sega CD Games: long (nullable = true)
#  |    |    |-- Sega CD Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sega Dreamcast Accessories: long (nullable = true)
#  |    |    |-- Sega Dreamcast Consoles: long (nullable = true)
#  |    |    |-- Sega Dreamcast Games: long (nullable = true)
#  |    |    |-- Sega Dreamcast Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sega Game Gear Accessories: long (nullable = true)
#  |    |    |-- Sega Game Gear Consoles: long (nullable = true)
#  |    |    |-- Sega Game Gear Games: long (nullable = true)
#  |    |    |-- Sega Game Gear Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sega Genesis Accessories: long (nullable = true)
#  |    |    |-- Sega Genesis Consoles: long (nullable = true)
#  |    |    |-- Sega Genesis Games: long (nullable = true)
#  |    |    |-- Sega Genesis Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sega Legacy Systems: long (nullable = true)
#  |    |    |-- Sega Master System Accessories: long (nullable = true)
#  |    |    |-- Sega Master System Consoles: long (nullable = true)
#  |    |    |-- Sega Master System Games: long (nullable = true)
#  |    |    |-- Sega Master System Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sega Saturn Accessories: long (nullable = true)
#  |    |    |-- Sega Saturn Consoles: long (nullable = true)
#  |    |    |-- Sega Saturn Games: long (nullable = true)
#  |    |    |-- Sega Saturn Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Smartwatch Cables & Chargers: long (nullable = true)
#  |    |    |-- Smoking Cessation Products: long (nullable = true)
#  |    |    |-- Snowshoes: long (nullable = true)
#  |    |    |-- Sony PSP Accessories: long (nullable = true)
#  |    |    |-- Sony PSP Accessory Kits: long (nullable = true)
#  |    |    |-- Sony PSP Adapters: long (nullable = true)
#  |    |    |-- Sony PSP Batteries: long (nullable = true)
#  |    |    |-- Sony PSP Cables: long (nullable = true)
#  |    |    |-- Sony PSP Cables & Adapters: long (nullable = true)
#  |    |    |-- Sony PSP Cases & Storage: long (nullable = true)
#  |    |    |-- Sony PSP Chargers: long (nullable = true)
#  |    |    |-- Sony PSP Consoles: long (nullable = true)
#  |    |    |-- Sony PSP Faceplates: long (nullable = true)
#  |    |    |-- Sony PSP Games: long (nullable = true)
#  |    |    |-- Sony PSP Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Sony PSP Headsets: long (nullable = true)
#  |    |    |-- Sony PSP Memory: long (nullable = true)
#  |    |    |-- Sony PSP Screen Protectors: long (nullable = true)
#  |    |    |-- Sony PSP Skins: long (nullable = true)
#  |    |    |-- Sony PSP Speakers: long (nullable = true)
#  |    |    |-- Sport Specific Clothing: long (nullable = true)
#  |    |    |-- Sports: long (nullable = true)
#  |    |    |-- Sports & Outdoor Recreation Accessories: long (nullable = true)
#  |    |    |-- Sports & Outdoors: long (nullable = true)
#  |    |    |-- Sports Fan Action Figures & Toy Figurines: long (nullable = true)
#  |    |    |-- Sports Fan Computer Accessories: long (nullable = true)
#  |    |    |-- Sports Fan Games: long (nullable = true)
#  |    |    |-- Sports Fan Shop: long (nullable = true)
#  |    |    |-- Sports Fan Tools & Home Improvement: long (nullable = true)
#  |    |    |-- Sports Fan Video Games & Accessories: long (nullable = true)
#  |    |    |-- Standalone Virtual Reality Accessories: long (nullable = true)
#  |    |    |-- Standalone Virtual Reality Hardware & Accessories: long (nullable = true)
#  |    |    |-- Standalone Virtual Reality Headsets: long (nullable = true)
#  |    |    |-- Stuffed Animals & Plush Toys: long (nullable = true)
#  |    |    |-- Styluses: long (nullable = true)
#  |    |    |-- Super Nintendo Accessories: long (nullable = true)
#  |    |    |-- Super Nintendo Consoles: long (nullable = true)
#  |    |    |-- Super Nintendo Games: long (nullable = true)
#  |    |    |-- Super Nintendo Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- TV: long (nullable = true)
#  |    |    |-- Table Tennis Racquets: long (nullable = true)
#  |    |    |-- Tablet Accessories: long (nullable = true)
#  |    |    |-- Tablet Chargers & Adapters: long (nullable = true)
#  |    |    |-- Tablet Keyboard Cases: long (nullable = true)
#  |    |    |-- Team Sports: long (nullable = true)
#  |    |    |-- Televisions & Video Products: long (nullable = true)
#  |    |    |-- Tools & Home Improvement: long (nullable = true)
#  |    |    |-- Toy Building Sets: long (nullable = true)
#  |    |    |-- Toy Figures & Playsets: long (nullable = true)
#  |    |    |-- Toy Foam Blasters: long (nullable = true)
#  |    |    |-- Toy Vehicles: long (nullable = true)
#  |    |    |-- Toys & Games: long (nullable = true)
#  |    |    |-- TurboGrafx 16 Accessories: long (nullable = true)
#  |    |    |-- TurboGrafx 16 Consoles: long (nullable = true)
#  |    |    |-- TurboGrafx 16 Games: long (nullable = true)
#  |    |    |-- USB Hubs: long (nullable = true)
#  |    |    |-- Unique Electronics: long (nullable = true)
#  |    |    |-- Unique Finds: long (nullable = true)
#  |    |    |-- Unique Gifts: long (nullable = true)
#  |    |    |-- Unique Home: long (nullable = true)
#  |    |    |-- Unique Kitchen: long (nullable = true)
#  |    |    |-- Unique Toys: long (nullable = true)
#  |    |    |-- Video Game Chairs: long (nullable = true)
#  |    |    |-- Video Game Consoles & Accessories: long (nullable = true)
#  |    |    |-- Video Games: long (nullable = true)
#  |    |    |-- Wall Stickers & Murals: long (nullable = true)
#  |    |    |-- Wearable Technology: long (nullable = true)
#  |    |    |-- Wii Accessories: long (nullable = true)
#  |    |    |-- Wii Accessory Kits: long (nullable = true)
#  |    |    |-- Wii Adapters: long (nullable = true)
#  |    |    |-- Wii Batteries: long (nullable = true)
#  |    |    |-- Wii Batteries & Chargers: long (nullable = true)
#  |    |    |-- Wii Cables: long (nullable = true)
#  |    |    |-- Wii Cables & Adapters: long (nullable = true)
#  |    |    |-- Wii Cases & Storage: long (nullable = true)
#  |    |    |-- Wii Chargers: long (nullable = true)
#  |    |    |-- Wii Consoles: long (nullable = true)
#  |    |    |-- Wii Controllers: long (nullable = true)
#  |    |    |-- Wii Cooling Systems: long (nullable = true)
#  |    |    |-- Wii Faceplates: long (nullable = true)
#  |    |    |-- Wii Fitness Accessories: long (nullable = true)
#  |    |    |-- Wii Game Dance Pads: long (nullable = true)
#  |    |    |-- Wii Game Drums: long (nullable = true)
#  |    |    |-- Wii Game Guitars: long (nullable = true)
#  |    |    |-- Wii Game Joysticks: long (nullable = true)
#  |    |    |-- Wii Game Keyboards: long (nullable = true)
#  |    |    |-- Wii Game Microphones: long (nullable = true)
#  |    |    |-- Wii Game Music Controllers: long (nullable = true)
#  |    |    |-- Wii Game Racing Wheels: long (nullable = true)
#  |    |    |-- Wii Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- Wii Games: long (nullable = true)
#  |    |    |-- Wii Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Wii Headsets: long (nullable = true)
#  |    |    |-- Wii Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Wii Memory: long (nullable = true)
#  |    |    |-- Wii Motion Controllers: long (nullable = true)
#  |    |    |-- Wii Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- Wii Protectors: long (nullable = true)
#  |    |    |-- Wii Remotes: long (nullable = true)
#  |    |    |-- Wii Sensor Bars: long (nullable = true)
#  |    |    |-- Wii Skins: long (nullable = true)
#  |    |    |-- Wii U Accessories: long (nullable = true)
#  |    |    |-- Wii U Accessory Kits: long (nullable = true)
#  |    |    |-- Wii U Adapters: long (nullable = true)
#  |    |    |-- Wii U Batteries: long (nullable = true)
#  |    |    |-- Wii U Batteries & Chargers: long (nullable = true)
#  |    |    |-- Wii U Cables: long (nullable = true)
#  |    |    |-- Wii U Cables & Adapters: long (nullable = true)
#  |    |    |-- Wii U Cases & Storage: long (nullable = true)
#  |    |    |-- Wii U Chargers: long (nullable = true)
#  |    |    |-- Wii U Consoles: long (nullable = true)
#  |    |    |-- Wii U Controllers: long (nullable = true)
#  |    |    |-- Wii U Faceplates: long (nullable = true)
#  |    |    |-- Wii U Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- Wii U Fitness Accessories: long (nullable = true)
#  |    |    |-- Wii U Game Racing Wheels: long (nullable = true)
#  |    |    |-- Wii U Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- Wii U Games: long (nullable = true)
#  |    |    |-- Wii U Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Wii U Headsets: long (nullable = true)
#  |    |    |-- Wii U Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Wii U Motion Controllers: long (nullable = true)
#  |    |    |-- Wii U Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- Wii U Protectors: long (nullable = true)
#  |    |    |-- Wii U Sensor Bars: long (nullable = true)
#  |    |    |-- Wii U Skins: long (nullable = true)
#  |    |    |-- Wine Chillers: long (nullable = true)
#  |    |    |-- Xbox 360 Accessories: long (nullable = true)
#  |    |    |-- Xbox 360 Accessory Kits: long (nullable = true)
#  |    |    |-- Xbox 360 Adapters: long (nullable = true)
#  |    |    |-- Xbox 360 Batteries: long (nullable = true)
#  |    |    |-- Xbox 360 Batteries & Chargers: long (nullable = true)
#  |    |    |-- Xbox 360 Cables: long (nullable = true)
#  |    |    |-- Xbox 360 Cables & Adapters: long (nullable = true)
#  |    |    |-- Xbox 360 Cases & Storage: long (nullable = true)
#  |    |    |-- Xbox 360 Chargers: long (nullable = true)
#  |    |    |-- Xbox 360 Consoles: long (nullable = true)
#  |    |    |-- Xbox 360 Controllers: long (nullable = true)
#  |    |    |-- Xbox 360 Cooling Systems: long (nullable = true)
#  |    |    |-- Xbox 360 Downloadable Content: long (nullable = true)
#  |    |    |-- Xbox 360 Faceplates: long (nullable = true)
#  |    |    |-- Xbox 360 Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- Xbox 360 Game Dance Pads: long (nullable = true)
#  |    |    |-- Xbox 360 Game Drums: long (nullable = true)
#  |    |    |-- Xbox 360 Game Guitars: long (nullable = true)
#  |    |    |-- Xbox 360 Game Joysticks: long (nullable = true)
#  |    |    |-- Xbox 360 Game Keyboards: long (nullable = true)
#  |    |    |-- Xbox 360 Game Microphones: long (nullable = true)
#  |    |    |-- Xbox 360 Game Music Controllers: long (nullable = true)
#  |    |    |-- Xbox 360 Game Music Keyboards: long (nullable = true)
#  |    |    |-- Xbox 360 Game Racing Wheels: long (nullable = true)
#  |    |    |-- Xbox 360 Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- Xbox 360 Games: long (nullable = true)
#  |    |    |-- Xbox 360 Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Xbox 360 Headsets: long (nullable = true)
#  |    |    |-- Xbox 360 Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Xbox 360 Memory: long (nullable = true)
#  |    |    |-- Xbox 360 Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- Xbox 360 Remotes: long (nullable = true)
#  |    |    |-- Xbox 360 Skins: long (nullable = true)
#  |    |    |-- Xbox 360 Thumb Grips: long (nullable = true)
#  |    |    |-- Xbox Accessories: long (nullable = true)
#  |    |    |-- Xbox Consoles: long (nullable = true)
#  |    |    |-- Xbox Games: long (nullable = true)
#  |    |    |-- Xbox Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Xbox Legacy Systems: long (nullable = true)
#  |    |    |-- Xbox Live Store Currency Cards: long (nullable = true)
#  |    |    |-- Xbox Live Subscriptions: long (nullable = true)
#  |    |    |-- Xbox One Accessories: long (nullable = true)
#  |    |    |-- Xbox One Accessory Kits: long (nullable = true)
#  |    |    |-- Xbox One Adapters: long (nullable = true)
#  |    |    |-- Xbox One Batteries: long (nullable = true)
#  |    |    |-- Xbox One Batteries & Chargers: long (nullable = true)
#  |    |    |-- Xbox One Battery & Charger Sets: long (nullable = true)
#  |    |    |-- Xbox One Cables: long (nullable = true)
#  |    |    |-- Xbox One Cables & Adapters: long (nullable = true)
#  |    |    |-- Xbox One Cases & Storage: long (nullable = true)
#  |    |    |-- Xbox One Chargers: long (nullable = true)
#  |    |    |-- Xbox One Consoles: long (nullable = true)
#  |    |    |-- Xbox One Consoles & Accessories: long (nullable = true)
#  |    |    |-- Xbox One Controllers: long (nullable = true)
#  |    |    |-- Xbox One Cooling Systems: long (nullable = true)
#  |    |    |-- Xbox One Downloadable Content: long (nullable = true)
#  |    |    |-- Xbox One Faceplates, Protectors & Skins: long (nullable = true)
#  |    |    |-- Xbox One Game Joysticks: long (nullable = true)
#  |    |    |-- Xbox One Game Racing Wheels: long (nullable = true)
#  |    |    |-- Xbox One Gamepads & Standard Controllers: long (nullable = true)
#  |    |    |-- Xbox One Games: long (nullable = true)
#  |    |    |-- Xbox One Games, Consoles & Accessories: long (nullable = true)
#  |    |    |-- Xbox One Headsets: long (nullable = true)
#  |    |    |-- Xbox One Interactive Gaming Figures: long (nullable = true)
#  |    |    |-- Xbox One Memory: long (nullable = true)
#  |    |    |-- Xbox One Mounts, Brackets & Stands: long (nullable = true)
#  |    |    |-- Xbox One Remotes: long (nullable = true)
#  |    |    |-- Xbox One Thumb Grips: long (nullable = true)
#  |    |    |-- Xbox Series X & S Accessories: long (nullable = true)
#  |    |    |-- Xbox Series X & S Accessory Kits: long (nullable = true)
#  |    |    |-- Xbox Series X & S Batteries & Chargers: long (nullable = true)
#  |    |    |-- Xbox Series X & S Cases & Storage: long (nullable = true)
#  |    |    |-- Xbox Series X & S Consoles: long (nullable = true)
#  |    |    |-- Xbox Series X & S Consoles, Games & Accessories: long (nullable = true)
#  |    |    |-- Xbox Series X & S Controllers: long (nullable = true)
#  |    |    |-- Xbox Series X & S Downloadable Content: long (nullable = true)
#  |    |    |-- Xbox Series X & S Faceplates: long (nullable = true)
#  |    |    |-- Xbox Series X & S Games: long (nullable = true)
#  |    |    |-- Xbox Series X & S Protectors: long (nullable = true)
#  |    |    |-- Xbox Series X & S Skin & Protector Sets: long (nullable = true)
#  |    |    |-- Xbox Series X & S Skins: long (nullable = true)
#  |    |    |-- Xbox Series X Cases: long (nullable = true)
#  |    |    |-- Xbox Series X Storage: long (nullable = true)
#  |    |-- Best uses: string (nullable = true)
#  |    |-- Bike Type: string (nullable = true)
#  |    |-- Binding: string (nullable = true)
#  |    |-- Biometric Security Feature: string (nullable = true)
#  |    |-- Blade Edge: string (nullable = true)
#  |    |-- Blade Length: string (nullable = true)
#  |    |-- Blade Material: string (nullable = true)
#  |    |-- Blade Shape: string (nullable = true)
#  |    |-- Blanket Form: string (nullable = true)
#  |    |-- Bluetooth Range: string (nullable = true)
#  |    |-- Bluetooth Version: string (nullable = true)
#  |    |-- Body Material: string (nullable = true)
#  |    |-- Body Shape: string (nullable = true)
#  |    |-- Bowl Material: string (nullable = true)
#  |    |-- Brand: string (nullable = true)
#  |    |-- Brand Name: string (nullable = true)
#  |    |-- Breed Recommendation: string (nullable = true)
#  |    |-- Brightness: string (nullable = true)
#  |    |-- Brightness Rating: string (nullable = true)
#  |    |-- Bristle Type: string (nullable = true)
#  |    |-- Built-in Light: string (nullable = true)
#  |    |-- Bulb Features: string (nullable = true)
#  |    |-- Bulb Shape Size: string (nullable = true)
#  |    |-- Bulb Type: string (nullable = true)
#  |    |-- Burner type: string (nullable = true)
#  |    |-- CD ROM: string (nullable = true)
#  |    |-- CPSIA Cautionary Statement: string (nullable = true)
#  |    |-- CPU Manufacturer: string (nullable = true)
#  |    |-- CPU Model: string (nullable = true)
#  |    |-- CPU Socket: string (nullable = true)
#  |    |-- CPU Speed: string (nullable = true)
#  |    |-- Cable Feature: string (nullable = true)
#  |    |-- Cable Length: string (nullable = true)
#  |    |-- Cable Type: string (nullable = true)
#  |    |-- Cache Size: string (nullable = true)
#  |    |-- Caffeine Content: string (nullable = true)
#  |    |-- Caller Identification: string (nullable = true)
#  |    |-- Camcorder type: string (nullable = true)
# ...
#  |    |-- Operating Voltage: string (nullable = true)
#  |    |-- Operation Mode: string (nullable = true)
#  |    |-- Optical Drive Type: string (nullable = true)
#  |    |-- Optical Sensor Technology: string (nullable = true)
#  |    |-- Optical Storage Device: string (nullable = true)
#  |    |-- Optical Zoom: string (nullable = true)
#  |    |-- Orientation: string (nullable = true)
#  |    |-- Original Release Date: string (nullable = true)
#  |    |-- Other camera features: string (nullable = true)
#  |    |-- Other display features: string (nullable = true)
#  |    |-- Our Recommended age: string (nullable = true)
#  |    |-- Outer Material: string (nullable = true)
#  |    |-- Outlet Connection Type: string (nullable = true)
#  |    |-- Output Current: string (nullable = true)
#  |    |-- Output Voltage: string (nullable = true)
#  |    |-- Output Wattage: string (nullable = true)
#  |    |-- PCI-Express Connector Configuration: string (nullable = true)
#  |    |-- Package Dimensions: string (nullable = true)
#  |    |-- Package Information: string (nullable = true)
#  |    |-- Package Type: string (nullable = true)
#  |    |-- Package Weight: string (nullable = true)
#  |    |-- Page numbers source ISBN: string (nullable = true)
#  |    |-- Paper Finish: string (nullable = true)
#  |    |-- Paperback: string (nullable = true)
#  |    |-- Part Number: string (nullable = true)
#  |    |-- Pattern: string (nullable = true)
#  |    |-- Pencil Lead Degree (Hardness): string (nullable = true)
#  |    |-- Perfect Paperback: string (nullable = true)
#  |    |-- Performance Description: string (nullable = true)
#  |    |-- Perfume: string (nullable = true)
#  |    |-- Personal computer design type: string (nullable = true)
#  |    |-- Phase Type: string (nullable = true)
#  |    |-- Phone Standby Time (with data): string (nullable = true)
#  |    |-- Phone Talk Time: string (nullable = true)
#  |    |-- Photo Sensor Technology: string (nullable = true)
#  |    |-- Pile Height: string (nullable = true)
#  |    |-- Pillow Type: string (nullable = true)
#  |    |-- Platform: string (nullable = true)
#  |    |-- Plug Format: string (nullable = true)
#  |    |-- Ply Rating: string (nullable = true)
#  |    |-- Pocket Description: string (nullable = true)
#  |    |-- Point Type: string (nullable = true)
#  |    |-- Polar Pattern: string (nullable = true)
#  |    |-- Position: string (nullable = true)
#  |    |-- Power Connector Type: string (nullable = true)
#  |    |-- Power Plug Type: string (nullable = true)
#  |    |-- Power Source: string (nullable = true)
#  |    |-- Power Source Type: string (nullable = true)
#  |    |-- Pre-printed: string (nullable = true)
#  |    |-- Pricing: string (nullable = true)
#  |    |-- Print length: string (nullable = true)
#  |    |-- Print media: string (nullable = true)
#  |    |-- Printer Output: string (nullable = true)
#  |    |-- Printing Technology: string (nullable = true)
#  |    |-- Processor: string (nullable = true)
#  |    |-- Processor Brand: string (nullable = true)
#  |    |-- Producers: string (nullable = true)
#  |    |-- Product Benefits: string (nullable = true)
#  |    |-- Product Care Instructions: string (nullable = true)
#  |    |-- Product Dimensions: string (nullable = true)
#  |    |-- Product Grade: string (nullable = true)
#  |    |-- Product Name: string (nullable = true)
#  |    |-- Publication Date: string (nullable = true)
#  |    |-- Publication date: string (nullable = true)
#  |    |-- Publisher: string (nullable = true)
#  |    |-- Pump type: string (nullable = true)
#  |    |-- Puzzle type: string (nullable = true)
#  |    |-- RAM: string (nullable = true)
#  |    |-- RAM Memory Maximum Size: string (nullable = true)
#  |    |-- RAM Memory Technology: string (nullable = true)
#  |    |-- Ram Memory Installed Size: string (nullable = true)
#  |    |-- Range: string (nullable = true)
#  |    |-- Rated: string (nullable = true)
#  |    |-- Read Speed: string (nullable = true)
#  |    |-- Reading age: string (nullable = true)
#  |    |-- Real Angle of View: string (nullable = true)
#  |    |-- Rear Webcam Resolution: string (nullable = true)
#  |    |-- Rear-facing maximum child weight: string (nullable = true)
#  |    |-- Rear-facing minimum child weight: string (nullable = true)
#  |    |-- Rechargeable Battery Included: string (nullable = true)
#  |    |-- Recommended Uses For Product: string (nullable = true)
#  |    |-- Recording Capacity: string (nullable = true)
#  |    |-- Refill: string (nullable = true)
#  |    |-- Refresh Rate: string (nullable = true)
#  |    |-- Refrigerator Fresh Food Capacity: string (nullable = true)
#  |    |-- Release date: string (nullable = true)
#  |    |-- Remote Control Included?: string (nullable = true)
#  |    |-- Resolution: string (nullable = true)
#  |    |-- Return Policy: string (nullable = true)
#  |    |-- Reusability: string (nullable = true)
#  |    |-- Roast Level: string (nullable = true)
#  |    |-- Rod Length: string (nullable = true)
#  |    |-- Room Type: string (nullable = true)
#  |    |-- Rug Form Type: string (nullable = true)
#  |    |-- Ruling: string (nullable = true)
#  |    |-- Ruling Type: string (nullable = true)
#  |    |-- Run time: string (nullable = true)
#  |    |-- Runtime: string (nullable = true)
#  |    |-- SPARS Code: string (nullable = true)
#  |    |-- Scanner Resolution: string (nullable = true)
#  |    |-- Scanner Type: string (nullable = true)
#  |    |-- Scent: string (nullable = true)
#  |    |-- Screen Reader: string (nullable = true)
#  |    |-- Screen Resolution: string (nullable = true)
#  |    |-- Screen Size: string (nullable = true)
#  |    |-- Screen Surface Description: string (nullable = true)
#  |    |-- Seasons: string (nullable = true)
#  |    |-- Seat Height: string (nullable = true)
#  |    |-- Seat Material Type: string (nullable = true)
#  |    |-- Seat Material Type Leather: string (nullable = true)
#  |    |-- Seat Material Type Memory Foam: string (nullable = true)
#  |    |-- Seat Width: string (nullable = true)
#  |    |-- Seat height: string (nullable = true)
#  |    |-- Secure Digital Association Speed Class: string (nullable = true)
#  |    |-- Security Protocol: string (nullable = true)
#  |    |-- Sensitivity: string (nullable = true)
#  |    |-- Series: string (nullable = true)
#  |    |-- Servings per Container: string (nullable = true)
#  |    |-- Shade Color: string (nullable = true)
#  |    |-- Shade Material: string (nullable = true)
#  |    |-- Shaft Material: string (nullable = true)
#  |    |-- Shape: string (nullable = true)
#  |    |-- Shape Arch & Bow: string (nullable = true)
#  |    |-- Shape Body: string (nullable = true)
#  |    |-- Shape Irregular: string (nullable = true)
#  |    |-- Shape Rectangular: string (nullable = true)
#  |    |-- Shape Round: string (nullable = true)
#  |    |-- Sheet Count: string (nullable = true)
#  |    |-- Sheet Size: string (nullable = true)
#  |    |-- Shelf Type: string (nullable = true)
#  |    |-- Shelf Type Glass: string (nullable = true)
#  |    |-- Shelf Type Hanging Shelf: string (nullable = true)
#  |    |-- Shell Type: string (nullable = true)
#  |    |-- Shelves: string (nullable = true)
#  |    |-- Shooting Modes: string (nullable = true)
#  |    |-- Signal Format: string (nullable = true)
#  |    |-- Signal-to-Noise Ratio: string (nullable = true)
#  |    |-- Simultaneous device usage: string (nullable = true)
#  |    |-- Size: string (nullable = true)
#  |    |-- Skill Level: string (nullable = true)
#  |    |-- Skin Tone: string (nullable = true)
#  |    |-- Skin Type: string (nullable = true)
#  |    |-- Soil Type: string (nullable = true)
#  |    |-- Sound Level: string (nullable = true)
#  |    |-- Speaker Maximum Output Power: string (nullable = true)
#  |    |-- Speaker Type: string (nullable = true)
#  |    |-- Speakers Maximum Output Power: string (nullable = true)
#  |    |-- Special Feature: string (nullable = true)
#  |    |-- Special Features: string (nullable = true)
#  |    |-- Special features: string (nullable = true)
#  |    |-- Specialty: string (nullable = true)
#  |    |-- Specific Uses: string (nullable = true)
#  |    |-- Specific Uses For Product: string (nullable = true)
#  |    |-- Specific instructions for use: string (nullable = true)
#  |    |-- Specification Met: string (nullable = true)
#  |    |-- Specifications: string (nullable = true)
#  |    |-- Spiral bound: string (nullable = true)
#  |    |-- Sport: string (nullable = true)
#  |    |-- Sport Type: string (nullable = true)
#  |    |-- Spout Height: string (nullable = true)
#  |    |-- Standing screen display size: string (nullable = true)
#  |    |-- Sticky notes: string (nullable = true)
#  |    |-- Strap Type: string (nullable = true)
#  |    |-- Studio: string (nullable = true)
#  |    |-- Style: string (nullable = true)
#  |    |-- Style Simple: string (nullable = true)
#  |    |-- Sub Brand: string (nullable = true)
#  |    |-- Subtitles: string (nullable = true)
#  |    |-- Subwoofer Diameter: string (nullable = true)
#  |    |-- Suggested Users: string (nullable = true)
#  |    |-- Suitable Hair Color: string (nullable = true)
#  |    |-- Sun Protection: string (nullable = true)
#  |    |-- Sunlight Exposure: string (nullable = true)
#  |    |-- Supported Audio Format: string (nullable = true)
#  |    |-- Supported Internet Services: string (nullable = true)
#  |    |-- Supported Standards: string (nullable = true)
#  |    |-- Surface Recommendation: string (nullable = true)
#  |    |-- Surface Recommendation Car: string (nullable = true)
#  |    |-- Surface Recommendation Envelope: string (nullable = true)
#  |    |-- Surface Recommendation Floor: string (nullable = true)
#  |    |-- Surface Recommendation Glass: string (nullable = true)
#  |    |-- Surface Recommendation Hard Floor,Carpets,Carpet: string (nullable = true)
#  |    |-- Surface Recommendation Hard Floors: string (nullable = true)
#  |    |-- Surface Recommendation Metal: string (nullable = true)
#  |    |-- Surface Recommendation Smooth: string (nullable = true)
#  |    |-- Surface Recommendation Tile,Carpet: string (nullable = true)
#  |    |-- Surface Recommendation Tile,Carpet,Floor: string (nullable = true)
#  |    |-- Surface Recommendation Wall: string (nullable = true)
#  |    |-- Surface Recommendation Window: string (nullable = true)
#  |    |-- Surface Recommendation Wood: string (nullable = true)
#  |    |-- Surface Recommendation non porous: string (nullable = true)
#  |    |-- Surround Sound Channel Configuration: string (nullable = true)
#  |    |-- Suspension Type: string (nullable = true)
#  |    |-- Switch Installation Type: string (nullable = true)
#  |    |-- Switch Style: string (nullable = true)
#  |    |-- Switch Type: string (nullable = true)
#  |    |-- Switch Type DIP Switch: string (nullable = true)
#  |    |-- Switch Type Pressure Switch, Push Button: string (nullable = true)
#  |    |-- Switch Type Pressure Switch, Temperature Switch: string (nullable = true)
#  |    |-- Switch Type Pressure Switch, Touch Switch: string (nullable = true)
#  |    |-- Switch Type Push Button: string (nullable = true)
#  |    |-- Switch Type Touch Switch, Temperature Switch: string (nullable = true)
#  |    |-- System Bus Standard Supported: string (nullable = true)
#  |    |-- TV Size: string (nullable = true)
#  |    |-- Table design: string (nullable = true)
#  |    |-- Target Audience: string (nullable = true)
#  |    |-- Target Gender: string (nullable = true)
#  |    |-- Target Species: string (nullable = true)
#  |    |-- Target gender: string (nullable = true)
#  |    |-- Team Name: string (nullable = true)
#  |    |-- Temperature Condition: string (nullable = true)
#  |    |-- Tension Level: string (nullable = true)
#  |    |-- Terminal: string (nullable = true)
#  |    |-- Terms of Use: string (nullable = true)
#  |    |-- Text to Speech: string (nullable = true)
#  |    |-- Theme: string (nullable = true)
#  |    |-- Thickness: string (nullable = true)
#  |    |-- Thread Count: string (nullable = true)
#  |    |-- Thread Coverage: string (nullable = true)
#  |    |-- Tick-repellent material: string (nullable = true)
#  |    |-- Tool Tip Description: string (nullable = true)
#  |    |-- Top Material: string (nullable = true)
#  |    |-- Top Material Type: string (nullable = true)
#  |    |-- Top Material Type Stainless Steel: string (nullable = true)
#  |    |-- Top Style: string (nullable = true)
#  |    |-- Total Eaches: string (nullable = true)
#  |    |-- Total HDMI Ports: string (nullable = true)
#  |    |-- Total Power Outlets: string (nullable = true)
#  |    |-- Total USB Ports: string (nullable = true)
#  |    |-- Toy: string (nullable = true)
#  |    |-- Tray Type: string (nullable = true)
#  |    |-- Tree Type: string (nullable = true)
#  |    |-- Tripod Head Type: string (nullable = true)
#  |    |-- Type: string (nullable = true)
#  |    |-- Type of Bulb: string (nullable = true)
#  |    |-- Type of item: string (nullable = true)
#  |    |-- UL Listed: string (nullable = true)
#  |    |-- UPC: string (nullable = true)
#  |    |-- Unit Count: string (nullable = true)
#  |    |-- Unit Grouping: string (nullable = true)
#  |    |-- Units: string (nullable = true)
#  |    |-- Unix System Requirements: string (nullable = true)
#  |    |-- Usage: string (nullable = true)
#  |    |-- Use for: string (nullable = true)
#  |    |-- Vehicle Service Type: string (nullable = true)
#  |    |-- Ventilation Type: string (nullable = true)
#  |    |-- Video Capture Format: string (nullable = true)
#  |    |-- Video Capture Resolution: string (nullable = true)
#  |    |-- Video Output Resolution: string (nullable = true)
#  |    |-- Viewing Angle: string (nullable = true)
#  |    |-- Viewing Area: string (nullable = true)
#  |    |-- Voltage: string (nullable = true)
#  |    |-- Voltage 12 Volts: string (nullable = true)
#  |    |-- Voltage 7.4 Volts: string (nullable = true)
#  |    |-- Volume: string (nullable = true)
#  |    |-- Wall Art Form: string (nullable = true)
#  |    |-- Warranty: string (nullable = true)
#  |    |-- Warranty Description: string (nullable = true)
#  |    |-- Warranty Type: string (nullable = true)
#  |    |-- Watch Movement: string (nullable = true)
#  |    |-- Water Resistance Depth: string (nullable = true)
#  |    |-- Water Resistance Level: string (nullable = true)
#  |    |-- Wattage: string (nullable = true)
#  |    |-- Weave Type: string (nullable = true)
#  |    |-- Weight: string (nullable = true)
#  |    |-- Weight Limit: string (nullable = true)
#  |    |-- Weighted Annual Energy Consumption: string (nullable = true)
#  |    |-- Whats in the box: string (nullable = true)
#  |    |-- Wheel Type: string (nullable = true)
#  |    |-- Windows System Requirements: string (nullable = true)
#  |    |-- Wireless Carrier: string (nullable = true)
#  |    |-- Wireless Comm Standard: string (nullable = true)
#  |    |-- Wireless Communication Standard: string (nullable = true)
#  |    |-- Wireless Communication Technology: string (nullable = true)
#  |    |-- Wireless Type: string (nullable = true)
#  |    |-- Wireless communication technologies: string (nullable = true)
#  |    |-- Wireless network technology: string (nullable = true)
#  |    |-- Word Wise: string (nullable = true)
#  |    |-- Write Speed: string (nullable = true)
#  |    |-- Writers: string (nullable = true)
#  |    |-- X Ray: string (nullable = true)
#  |    |-- Year: string (nullable = true)
#  |    |-- null: string (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- hi_res: string (nullable = true)
#  |    |    |-- large: string (nullable = true)
#  |    |    |-- thumb: string (nullable = true)
#  |    |    |-- variant: string (nullable = true)
#  |-- main_category: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rating_number: long (nullable = true)
#  |-- store: string (nullable = true)
#  |-- subtitle: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- videos: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user_id: string (nullable = true)

# %%
metadata_df = metadata_df.drop('images', 'videos', 'details', "description", "features", "author", "subtitle", "bought_together")

# %%
metadata_df.printSchema()
# Out:
# root
#  |-- average_rating: double (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- main_category: string (nullable = true)
#  |-- parent_asin: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rating_number: long (nullable = true)
#  |-- store: string (nullable = true)
#  |-- title: string (nullable = true)

# %%
metadata_df = metadata_df.select("parent_asin", "title", "average_rating", "rating_number", "main_category", "categories", "price", "store")

# %%
metadata_df.write.mode("overwrite").parquet("Dataset/metadata.parquet")
